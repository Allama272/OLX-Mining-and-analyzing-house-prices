# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df=pd.read_csv('Data/clean_main_data.csv')
df.head()
# Out:
#      Price  Bedrooms  Bathrooms  Area     Location
# 0   500000         3          1   120        Miami
# 1  3600000         4          3   265       Louran
# 2  6500000         2          3   214  San Stefano
# 3  3060000         3          3   204  San Stefano
# 4  2500000         3          3   165       Louran

# %%
df.describe()
# Out:
#               Price  Bedrooms  Bathrooms       Area
# count      8955.000  8955.000   8955.000   8955.000
# mean    1705347.627     2.685      1.651    397.880
# std     3431809.547     0.737      0.804  11588.044
# min       30000.000     1.000      1.000     10.000
# 25%      375000.000     2.000      1.000    110.000
# 50%     1100000.000     3.000      1.000    135.000
# 75%     2400000.000     3.000      2.000    175.000
# max   256988515.000    10.000     10.000 950000.000

# %%
df['Price'].min()
# Out:
# 30000

# %%
df['Price'].max()
# Out:
# 256988515

# %%
sns.scatterplot(data=df, x='Price', y='Price')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Price'>

# %%
sns.set(rc={'figure.figsize':(12,9)})

df['Price'].hist()
# Out:
# <AxesSubplot:>

# %%
df.sort_values(by='Price', ascending=False).head(50)
# Out:
#           Price  Bedrooms  Bathrooms    Area         Location
# 847   256988515         3          2     148          Roushdy
# 8877   80000000         2          1      70         Maamoura
# 3778   50000000         6          7    1075          Roushdy
# 8800   50000000         7          8   10000          Stanley
# 2245   27000000        10         10     600        Kafr Abdo
# 8341   25000000         3          2     150         Maamoura
# 2751   22000000         3          2    2220            Smoha
# 1014   21000000         4          5     600      San Stefano
# 7076   20000000         2          1     100            Agami
# 6366   20000000         6          4     385      San Stefano
# 6553   19000000         4          5     600      San Stefano
# 1083   19000000         9          9     750      Camp Caesar
# 1490   18000000         4          5     600      San Stefano
# 1322   17400000         1          1     120           Louran
# 8554   17000000         1          1      55          Nakheel
# 2365   16000000         4          5     600      San Stefano
# 868    16000000         6          5     600      San Stefano
# 1827   16000000         6          4     600           Louran
# 6146   16000000        10         10     330  Al Ibrahimiyyah
# 8047   15000000         4          1     160  Al Ibrahimiyyah
# 5641   15000000         4          3     500         Sporting
# 565    15000000         2          2     160     Raml Station
# 7242   14000000         2          1     120         Maamoura
# 1062   13000000         8          3     280            Smoha
# 4430   13000000         4          3     292      San Stefano
# 867    13000000         7          5     580           Louran
# 6828   13000000         3          3     500          Azarita
# 4863   13000000         4          3     292       Saba Pasha
# 1065   12500000         5          6     575            Smoha
# 4184   12500000         4          3     292      San Stefano
# 6808   12000000         5          6     575            Smoha
# 5647   12000000         4          3     292      San Stefano
# 8506   12000000         4          3     292      San Stefano
# 421    12000000         3          4     400       Saba Pasha
# 4439   12000000         4          4     335          Zezenia
# 6927   12000000         4          4     320      San Stefano
# 3989   11750000         4          4     292      San Stefano
# 172    11500000         4          3     300           Louran
# 253    11200000         4          4     460           Louran
# 6751   11111111         4          1  111111        Kafr Abdo
# 5296   11000000         3          4     400          Stanley
# 345    11000000         3          4     270      San Stefano
# 3215   11000000         6          5     900          Stanley
# 4784   11000000         4          3     270      San Stefano
# 891    11000000         3          4     270      San Stefano
# 2018   11000000         4          4     270      San Stefano
# 6484   10600000         4          3     265             Glim
# 6421   10150000         3          4     400             Glim
# 4435   10000000         4          5     390          Zezenia
# 2859   10000000         5          4     610            Miami

# %% [markdown]
# ## We got some outliers that we need to drop, lets drop rows >=5mil since we are not focusing on such high prices in this analysis

# %%
df[df['Price']>5000000].count()
# Out:
# Price        339
# Bedrooms     339
# Bathrooms    339
# Area         339
# Location     339
# dtype: int64

# %%
df[df['Price']<5000000].count()
# Out:
# Price        8593
# Bedrooms     8593
# Bathrooms    8593
# Area         8593
# Location     8593
# dtype: int64

# %%
df=df[df['Price']<5000000]

# %%
df['Price'].max()
# Out:
# 4976147

# %%
sns.set(rc={'figure.figsize':(12,9)})

df['Price'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## The data is very right skewed

# %%
df.groupby('Location').size().sort_values(ascending=False)
# Out:
# Location
# Nakheel             1940
# Smoha               1253
# Agami                760
# Sidi Beshr           510
# Miami                423
# Louran               353
# Moharam Bik          317
# Mandara              231
# Roushdy              191
# Glim                 186
# Seyouf               185
# Kafr Abdo            162
# Saba Pasha           149
# Asafra               147
# Al Ibrahimiyyah      141
# Sidi Gaber           125
# Maamoura             125
# Sporting             107
# Gianaclis             93
# Cleopatra             88
# San Stefano           81
# Montazah              77
# Zezenia               77
# Bolkly                72
# Stanley               70
# Fleming               67
# Camp Caesar           67
# Victoria              64
# Abu Qir               55
# Al Hadrah             55
# Azarita               45
# Bacchus               40
# Awayed                37
# Abu Talat             32
# Raml Station          28
# Bahray - Anfoshy      24
# Borg al-Arab          24
# Amreya                22
# Schutz                20
# Wardian               18
# Dekheila              18
# Karmous               18
# Attarin               17
# Manshiyya             17
# Shatby                15
# Gomrok                10
# Kabbary                9
# Ras El Tin             8
# Labban                 6
# Dhahria                6
# El Max                 6
# Salehia                1
# Koum al-Dikka          1
# dtype: int64

# %%
location_price=df.groupby('Location').agg({"Price": np.mean, }).sort_values(by='Price', ascending=False)
location_price= location_price.reset_index()
location_price
# Out:
#             Location       Price
# 0        San Stefano 4938050.154
# 1            Roushdy 4407749.277
# 2       Raml Station 4029935.949
# 3            Stanley 3956392.405
# 4               Glim 3540189.022
# 5            Kabbary 3453000.000
# 6            Zezenia 3328292.157
# 7            Azarita 3235482.830
# 8          Kafr Abdo 3230387.277
# 9        Camp Caesar 3124477.564
# 10        Saba Pasha 3022733.734
# 11          Sporting 2852826.250
# 12             Smoha 2847425.541
# 13            Louran 2789774.149
# 14            Shatby 2670312.500
# 15       Moharam Bik 2397872.537
# 16          Maamoura 2271215.385
# 17   Al Ibrahimiyyah 2182483.265
# 18         Cleopatra 2012956.989
# 19        Sidi Gaber 1905884.524
# 20         Gianaclis 1821989.247
# 21            Bolkly 1647708.333
# 22            El Max 1642857.143
# 23         Manshiyya 1625526.316
# 24          Montazah 1411461.538
# 25            Amreya 1326101.600
# 26           Fleming 1313411.765
# 27      Borg al-Arab 1266228.440
# 28           Mandara 1260080.971
# 29             Miami 1228415.225
# 30        Ras El Tin 1200625.000
# 31        Sidi Beshr 1127240.802
# 32            Asafra 1028729.730
# 33  Bahray - Anfoshy  927291.667
# 34          Victoria  852307.692
# 35     Koum al-Dikka  850000.000
# 36         Al Hadrah  832090.891
# 37            Seyouf  824371.505
# 38            Gomrok  731000.000
# 39           Attarin  712941.176
# 40           Abu Qir  646181.818
# 41            Schutz  589000.000
# 42          Dekheila  587500.000
# 43           Wardian  583055.556
# 44           Bacchus  493625.000
# 45             Agami  444195.861
# 46            Labban  431666.667
# 47            Awayed  386081.081
# 48           Nakheel  346060.278
# 49         Abu Talat  343356.250
# 50           Dhahria  287500.000
# 51           Karmous  280277.778
# 52           Salehia  120000.000

# %%
location_price.columns
# Out:
# Index(['Price'], dtype='object')

# %%
fig, ax = plt.subplots(figsize=(18, 6))
ax.tick_params(axis='x', rotation=90)

plt.ticklabel_format(style='plain', axis='y')

sns.barplot(data=location_price, x='Location', y='Price',)
# Out:
# <AxesSubplot:xlabel='Location', ylabel='Price'>
